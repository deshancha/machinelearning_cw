# %% [markdown]
# # Task 3: Model Development and Optimization
#
# Usecases `TrainAndTuneUseCase` to split dataset features, preprocess (scale,encode), tuning 5 models, best model serialization, and comparison usingF1 scoe.

# %%
import os
import sys
sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), 'src')))

from di.container import AppContainer

from dotenv import load_dotenv
load_dotenv()

# DI Container
container = AppContainer()
container.config.from_dict({
    "data": {
        "data_dir": os.path.join(os.getcwd(), "data")
    }
})

# %%
# Execute pipelines -> tune, evaluate, and save
train_usecase = container.train_and_tune_usecase()
model_dir = os.path.join(os.getcwd(), "outputs/models")
output_summary_path = os.path.join(os.getcwd(), "outputs/model_development_summary.csv")

results_df = train_usecase.execute(model_dir, output_summary_path)
results_df
# Out:
# 2026-07-30 14:41:56,276 | INFO     | [ML_CW] Loaded processed data: 45175 rows
# 2026-07-30 14:41:56,297 | INFO     | [ML_CW] Training set shape: 36140 rows x 18 features
# 2026-07-30 14:41:56,302 | INFO     | [ML_CW] Numerical columns: ['age', 'education-num', 'capital-gain', 'capital-loss', 'hours-per-week', 'capital_net', 'has_capital']
# 2026-07-30 14:41:56,303 | INFO     | [ML_CW] Categorical columns: ['workclass', 'education', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'native-country', 'age_group', 'hours_category', 'edu_group']
# 2026-07-30 14:41:56,304 | INFO     | [ML_CW] --- Tuning & Evaluating: Logistic Regression ---
# /Users/chamikadeshan/Documents/DataScience/MSc/Repos/ML_CW/.venv/lib/python3.9/site-packages/sklearn/model_selection/_search.py:317: UserWarning: The total space of parameters 4 is smaller than n_iter=10. Running 4 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# ...
