# %% [markdown]
# # Task 3: Model Development and Optimization
#
# Usecases `TrainAndTuneUseCase` to split dataset features, preprocess (scale,encode), tuning 5 models, best model serialization, and comparison usingF1 scoe.

# %%
import os
import sys
sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), 'src')))

from di.container import AppContainer

# DI Container
container = AppContainer()
container.config.from_dict({
    "data": {
        "data_dir": os.path.join(os.getcwd(), "data")
    }
})

# %%
# Execute pipelines -> tune, evaluate, and save
train_usecase = container.train_and_tune_usecase()
model_dir = os.path.join(os.getcwd(), "outputs/models")
output_summary_path = os.path.join(os.getcwd(), "outputs/model_development_summary.csv")

results_df = train_usecase.execute(model_dir, output_summary_path)
results_df
# Out:
# 2026-07-18 01:20:53,940 | INFO     | [ML_CW] Loaded processed data: 45175 rows
# 2026-07-18 01:20:53,956 | INFO     | [ML_CW] Training set shape: 36140 rows x 18 features
# 2026-07-18 01:20:53,961 | INFO     | [ML_CW] Numerical columns: ['age', 'education-num', 'capital-gain', 'capital-loss', 'hours-per-week', 'capital_net', 'has_capital']
# 2026-07-18 01:20:53,962 | INFO     | [ML_CW] Categorical columns: ['workclass', 'education', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'native-country', 'age_group', 'hours_category', 'edu_group']
# 2026-07-18 01:20:53,963 | INFO     | [ML_CW] --- Tuning & Evaluating: XGBoost ---
# 2026-07-18 01:20:53,964 | INFO     | [ML_CW] Calculated class ratio scaling weight: 3.033
# 2026-07-18 01:21:06,295 | INFO     | [ML_CW] Best parameters: {'clf__learning_rate': 0.2, 'clf__max_depth': 5, 'clf__n_estimators': 200}
# 2026-07-18 01:21:06,296 | INFO     | [ML_CW] Best CV F1: 0.7195
# 2026-07-18 01:21:06,303 | INFO     | [ML_CW] Summary Table:
#          CV F1-Score
# XGBoost       0.7195
# 2026-07-18 01:21:06,304 | INFO     | [ML_CW] Processed data saved successfully /Users/chamikadeshan/Documents/DataScience/MSc/Repos/ML_CW/Q1/outputs/model_development_summary.csv
# 2026-07-18 01:21:06,305 | INFO     | [ML_CW] TrainAndTuneUseCase execution complete.
#          CV F1-Score
# XGBoost     0.719514
